# %% [markdown]
# #### Calculo
#
# El calculo es el área de las matematicas que estudia la variación y movimiento de un objeto. Permite observar y describir la realidad en terminos dinamicos
#
# #### Calculo infinitesimal
#
# Se centra en tratar con distintas operaciones matematicas que se relaciones con canidades infinitamente pequeñas
#
# #### Función
#
# Relación establecida entre dos conjuntos A y B que asigna a cada valor del conjunto A(variable independiente) un unico valor del conjunto B(variable dependiente)
#
# #### Dominio de la función
#
# Todos los valores posibles de la variable independiente (valores q x va a tomar)
#
# #### Rango de la función
#
# Conjunto de todos los valores posibles de la variable dependiente (valores q y va a tomar)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Función lineal
#
# Tiene la forma de: 𝑓(𝑥)=𝑚𝑥+𝑏
#
# donde  𝑚  y  𝑏   ∈𝑅 .
#
# 𝑚  puede ser calculada por:
# 𝑚=(𝑦2−𝑦1) / (𝑥2−𝑥1) y  𝑏, es el punto de corte con el eje  𝑦.
#
# Su dominio es  𝐷𝑜𝑚𝑓=(−∞,∞) . Su Rango es  𝐼𝑚𝑓=(−∞,∞)

# %%
#Puntos de ejemplo (2,4) y (3,5)
m=(5-4)/(3-2)
m
# Out:
# 1.0

# %%
#Rango en el que se va a evaluar la funcion
x=np.linspace(-10,10,1000) #Numero inicial, numero final, cantidad de espacios entre estos
x
# Out:
# array([-10.        ,  -9.97997998,  -9.95995996,  -9.93993994,
#         -9.91991992,  -9.8998999 ,  -9.87987988,  -9.85985986,
#         -9.83983984,  -9.81981982,  -9.7997998 ,  -9.77977978,
#         -9.75975976,  -9.73973974,  -9.71971972,  -9.6996997 ,
#         -9.67967968,  -9.65965966,  -9.63963964,  -9.61961962,
#         -9.5995996 ,  -9.57957958,  -9.55955956,  -9.53953954,
#         -9.51951952,  -9.4994995 ,  -9.47947948,  -9.45945946,
#         -9.43943944,  -9.41941942,  -9.3993994 ,  -9.37937938,
#         -9.35935936,  -9.33933934,  -9.31931932,  -9.2992993 ,
#         -9.27927928,  -9.25925926,  -9.23923924,  -9.21921922,
#         -9.1991992 ,  -9.17917918,  -9.15915916,  -9.13913914,
#         -9.11911912,  -9.0990991 ,  -9.07907908,  -9.05905906,
#         -9.03903904,  -9.01901902,  -8.998999  ,  -8.97897898,
#         -8.95895896,  -8.93893894,  -8.91891892,  -8.8988989 ,
#         -8.87887888,  -8.85885886,  -8.83883884,  -8.81881882,
# ...

# %%
#Evaluamos la función en el rango y con los datos
b=1 #Valor en el que nuestra funcipon cortara la linea de los ejes de la y, puede cambiar
y=lambda x: m*x+b
print(y(x))
# Out:
# [-9.         -8.7979798  -8.5959596  -8.39393939 -8.19191919 -7.98989899
#  -7.78787879 -7.58585859 -7.38383838 -7.18181818 -6.97979798 -6.77777778
#  -6.57575758 -6.37373737 -6.17171717 -5.96969697 -5.76767677 -5.56565657
#  -5.36363636 -5.16161616 -4.95959596 -4.75757576 -4.55555556 -4.35353535
#  -4.15151515 -3.94949495 -3.74747475 -3.54545455 -3.34343434 -3.14141414
#  -2.93939394 -2.73737374 -2.53535354 -2.33333333 -2.13131313 -1.92929293
#  -1.72727273 -1.52525253 -1.32323232 -1.12121212 -0.91919192 -0.71717172
#  -0.51515152 -0.31313131 -0.11111111  0.09090909  0.29292929  0.49494949
#   0.6969697   0.8989899   1.1010101   1.3030303   1.50505051  1.70707071
#   1.90909091  2.11111111  2.31313131  2.51515152  2.71717172  2.91919192
#   3.12121212  3.32323232  3.52525253  3.72727273  3.92929293  4.13131313
#   4.33333333  4.53535354  4.73737374  4.93939394  5.14141414  5.34343434
#   5.54545455  5.74747475  5.94949495  6.15151515  6.35353535  6.55555556
# ...

# %%
fig, ax = plt.subplots()
ax.plot(x,y(x),color='red')
ax.grid()
ax.axhline(y=0, color='black')
ax.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### Composición de funciones

# %%
x=np.linspace(-20,20,100)
cuadrado=lambda x: x**2#g
#print(cuadrado(cuadrado(x)))

seno=lambda x: np.sin(x)#f
#print(seno(x))

_,fig1=plt.subplots()
fig1.plot(x,cuadrado(x),color='red')
fig1.grid()
fig1.axhline(y=0, color='black')
fig1.axvline(x=0, color='black')
_,fig2=plt.subplots()
fig2.plot(x,seno(x),color='red')
fig2.grid()
fig2.axhline(y=0, color='black')
fig2.axvline(x=0, color='black')
plt.show()

# %%
fog=lambda x: seno(cuadrado(x))
_,figfog=plt.subplots()
figfog.plot(x,fog(x),color='r')
figfog.grid()
figfog.axhline(y=0, color='black')
figfog.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# ##### 1) Graficar la funcion f(x)=x

# %%
x= np.linspace(-10,10,1000)
y=lambda x: x
_,fig3=plt.subplots()
fig3.plot(x,y(x),color='red')
fig3.grid()
fig3.axhline(y=0, color='black')
fig3.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### 2) Graficar la funcion f(x)=mx donde m=2

# %%
#Ya creamos los puntos en los que será evaluada nuestra funcion (x)
m=2
f=lambda x: x*m
_,fig4=plt.subplots()
fig4.plot(x,f(x),color='red')
fig4.grid()
fig4.axhline(y=0, color='black')
fig4.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### 3) Graficar la funcion f(x)=mx+b donde m=1 y b=5

# %%
m=1
b=5
f=lambda x: m*x+b
_,fig5=plt.subplots()
fig5.plot(x,f(x),color='red')
fig5.grid()
fig5.axhline(y=0, color='black')
fig5.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### 4) Graficar la funcion f(g(x)) siendo f(x)=3x+2 y g(x)=2x

# %%
#f=3*x+2
#g=2*x
fg=lambda x: 3*(2*x)+2
fg(x)
_,fig6=plt.subplots()
fig6.plot(x,fg(x),color='red')
fig6.grid()
fig6.axhline(y=0, color='black')
fig6.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### 5) Graficar la funcion f(g(x)) siendo f(x)=sin(x) y g(x)=1/x

# %%
#f(x)=sin(x)
#g(x)=1/x
fg2=lambda x: np.sin(1/x)
_,fig6=plt.subplots()
fig6.plot(x,fg2(x),color='red')
fig6.grid()
fig6.axhline(y=0, color='black')
fig6.axvline(x=0, color='black')
plt.show()

# %% [markdown]
# #### 6) Graficar la función f(g(x)), siendo f(x)=2x+1 y, g(x)=cos(x)

# %%
#f(x)=2+1
#g(x)=cos(x)
fg3=lambda x: 2*(np.cos(x))+1
_,fig7=plt.subplots()
fig7.plot(x,fg3(x),color='red')
fig7.grid()
fig7.axhline(y=0, color='black')
fig7.axvline(x=0, color='black')
plt.show()
